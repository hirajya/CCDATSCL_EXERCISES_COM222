# %% [markdown]
# <a href="https://colab.research.google.com/github/hirajya/CCDATSCL_EXERCISES_COM222/blob/main/Exercise5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 5

# %%
import pandas as pd
import numpy as np

from scipy import stats
from scipy.stats import chi2_contingency

# %% [markdown]
# ## Part 1: ANOVA
#
# A teacher wants to investigate whether different teaching methods affect students’ exam scores. The dataset contains 50 students, each assigned to one of three teaching methods (A, B, or C).
#
# Question: "Is there a difference in mean exam scores among students taught using three different teaching methods?"
#
# - Independent variable (factor): Teaching Method (A, B, C)
# - Dependent variable: Exam Score (numeric)

# %%
url = "https://github.com/robitussin/CCDATSCL_EXERCISES/blob/f56f00991116fcb717a8827d324aa6f599dea366/exam_scores.csv?raw=true"

df_exam_scores = pd.read_csv(url)
df_exam_scores
# Out:
#     StudentID Method  Score
# 0           1      A     79
# 1           2      A     77
# 2           3      A     82
# 3           4      A     75
# 4           5      A     80
# 5           6      A     78
# 6           7      A     83
# 7           8      A     76
# 8           9      A     81
# 9          10      A     74
# 10         11      A     79
# 11         12      A     77
# 12         13      A     80
# 13         14      A     78
# 14         15      A     76
# 15         16      A     82
# 16         17      A     79
# 17         18      B     88
# 18         19      B     85
# 19         20      B     82
# 20         21      B     87
# 21         22      B     90
# 22         23      B     84
# 23         24      B     86
# 24         25      B     83
# 25         26      B     88
# 26         27      B     85
# 27         28      B     86
# 28         29      B     87
# 29         30      B     89
# 30         31      B     84
# 31         32      B     90
# 32         33      B     85
# 33         34      B     88
# 34         35      C     70
# 35         36      C     74
# 36         37      C     72
# 37         38      C     71
# 38         39      C     73
# 39         40      C     69
# 40         41      C     72
# 41         42      C     75
# 42         43      C     70
# 43         44      C     74
# 44         45      C     71
# 45         46      C     73
# 46         47      C     72
# 47         48      C     74
# 48         49      C     70
# 49         50      C     71

# %% [markdown]
# Calculate the number of students in each teaching method.

# %%
df_exam_scores = df_exam_scores.drop(columns=['StudentID'])

# %%
df_class = df_exam_scores.groupby('Method').count()
df_class
# Out:
#         Score
# Method
# A          17
# B          17
# C          16

# %% [markdown]
# Compute the mean and standard deviation of exam scores for each group.

# %%
df_exam_scores.groupby('Method')['Score'].agg(['mean', 'std'])
# Out:
#              mean       std
# Method
# A       78.588235  2.575336
# B       86.294118  2.365500
# C       71.937500  1.768945

# %% [markdown]
# Use a plot to show the exam scores by teaching method.

# %%
# put your answer here

# %%
df_exam_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Method  50 non-null     object
#  1   Score   50 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 932.0+ bytes

# %% [markdown]
# Perform the ANOVA Test
# - Use scipy.stats.f_oneway to conduct a one-way ANOVA.
# - Report the F-statistic and p-value.
# - Using a significance level of α = 0.05, state whether you reject or fail to reject H₀.

# %%
group_a = df_exam_scores[df_exam_scores['Method'] == "A"]['Score']
group_b = df_exam_scores[df_exam_scores['Method'] == "B"]['Score']
group_c = df_exam_scores[df_exam_scores['Method'] == "C"]['Score']

f_val, p_val = stats.f_oneway(group_a, group_b, group_c)

# %% [markdown]
# Interpret the results. What does it say about the relationship between teaching method and exam scores?

# %%
print(f"F-Statistic: {f_val}, P-Value: {p_val}")
# Out:
# F-Statistic: 165.17845596593054, P-Value: 5.5032645988699085e-22

# %%
alpha = 0.05
if p_val < alpha:
  print("Significant difference found (Reject H0)")
else:
  print("No significant difference found (Fail to reject H0)")
# Out:
# Significant difference found (Reject H0)

# %% [markdown]
# With F(·,·) = 165.18 and p = 5.50 × 10⁻²² < 0.05, the null hypothesis is rejected. This suggests a statistically significant difference in mean exam scores among the teaching methods.

# %% [markdown]
# ## Part 2: Chi-squared
#
# A survey was conducted to see if there is a relationship between gender and littering behavior.
#
# Question:
# "Is gender associated with littering behavior?"
#
# Each row represents one person.

# %%
url = "https://github.com/robitussin/CCDATSCL_EXERCISES/blob/f56f00991116fcb717a8827d324aa6f599dea366/litteringdata.csv?raw=true"

df_littering_data = pd.read_csv(url)
df_littering_data
# Out:
#     ID  Gender Litter
# 0    1    Male    Yes
# 1    2    Male    Yes
# 2    3    Male    Yes
# 3    4    Male    Yes
# 4    5    Male    Yes
# 5    6    Male    Yes
# 6    7    Male    Yes
# 7    8    Male    Yes
# 8    9    Male    Yes
# 9   10    Male    Yes
# 10  11    Male    Yes
# 11  12    Male    Yes
# 12  13    Male     No
# 13  14    Male     No
# 14  15    Male     No
# 15  16    Male     No
# 16  17    Male     No
# 17  18    Male     No
# 18  19    Male     No
# 19  20    Male     No
# 20  21  Female    Yes
# 21  22  Female    Yes
# 22  23  Female    Yes
# 23  24  Female    Yes
# 24  25  Female    Yes
# 25  26  Female    Yes
# 26  27  Female     No
# 27  28  Female     No
# 28  29  Female     No
# 29  30  Female     No
# 30  31  Female     No
# 31  32  Female     No
# 32  33  Female     No
# 33  34  Female     No
# 34  35  Female     No
# 35  36  Female     No
# 36  37  Female     No
# 37  38  Female     No
# 38  39  Female     No
# 39  40  Female     No

# %%
df_littering_data = df_littering_data.drop(columns=['ID'])

# %% [markdown]
# Count the number of observations in each category for Gender and Litter separately.

# %%
df_littering_data[['Gender', 'Litter']].apply(pd.Series.value_counts)
# Out:
#         Gender  Litter
# Female    20.0     NaN
# Male      20.0     NaN
# No         NaN    22.0
# Yes        NaN    18.0

# %%
gender_counts = df_littering_data['Gender'].value_counts()

litter_counts = df_littering_data['Litter'].value_counts()

print("Gender counts:\n", gender_counts)
print("\nLitter counts:\n", litter_counts)
# Out:
# Gender counts:
#  Gender
# Male      20
# Female    20
# Name: count, dtype: int64
#
# Litter counts:
#  Litter
# No     22
# Yes    18
# Name: count, dtype: int64

# %% [markdown]
# Using `pd.crosstab()`, create a contingency table showing counts of littering behavior for each gender.
# - Write down the row totals, column totals, and grand total from the table.

# %%
contingency_table = pd.crosstab(df_littering_data['Gender'], df_littering_data['Litter'])
contingency_table
# Out:
# Litter  No  Yes
# Gender
# Female  14    6
# Male     8   12

# %% [markdown]
# State the null hypothesis (H₀) and alternative hypothesis (H₁) for this chi-squared test.

# %%
chi2, p, dof, expected = chi2_contingency(contingency_table)

# %% [markdown]
# Use scipy.stats.chi2_contingency to calculate:
# - Chi-squared statistic
# - p-value
# - Degrees of freedom

# %%
print(f"Chi-Square Statistic: {chi2:.4f}")
print(f"P-value: {p:.4f}")
print(f"Degrees of freedom: {dof:.4f}")
# Out:
# Chi-Square Statistic: 2.5253
# P-value: 0.1120
# Degrees of freedom: 1.0000

# %% [markdown]
# Using a significance level of `α = 0.05`, determine whether to reject or fail to reject H₀.

# %%
alpha = 0.05

# %% [markdown]
# Interpret your results. Is there evidence that gender and littering behavior are associated?

# %%
if p < alpha:
  print("Significant difference found (Reject H0)")
else:
  print("No significant difference found (Fail to reject H0)")
# Out:
# No significant difference found (Fail to reject H0)
